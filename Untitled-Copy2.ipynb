# %%
import pandas as pd
# import gensim

# %%
messages = pd.read_csv('SMSSpamCollection.txt', sep = '\t', names=['label','message'])

# %%
# DATA PREPREOCESSING
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
corpus = []
for i in range(len(messages)):
    review = re.sub('[^a-zA-Z]', ' ', messages['message'][i])
    review = review.lower()
    review = review.split()

    # review = [lemmatizer.lemmatize(word) for word in review if not word in stopwords.words('english')]
    review = [lemmatizer.lemmatize(word) for word in review ] 
    review = ' '.join(review)
    corpus.append(review)

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,

# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api
wv = api.load('word2vec-google-news-300')

# %%
words = []
for sent in corpus:
    sent_token = sent_tokenize(sent)
    for sent in sent_token:
        words.append(simple_preprocess(sent))

# %%
words[1]
# Out:
# ['ok', 'lar', 'joking', 'wif', 'oni']

# %%
model = gensim.models.Word2Vec(words)

# %%
model.corpus_count
# Out:
# 5569

# %%
model.epochs
# Out:
# 5

# %%
# model.wv.similar_by_word('good')

# %%
# model.wv.similar_by_word('kid')

# %%
def avg_word2vec(doc):
    vectors = [model.wv[word] for word in doc if word in model.wv.index_to_key]
    if len(vectors) > 0:
        return np.mean(vectors, axis=0)
    else:
        return np.zeros(model.vector_size)  # Trả về vector toàn số 0

# %%
from tqdm import tqdm

# %%
import numpy as np
X = []
for i in tqdm(range(len(words))):
    X.append(avg_word2vec(words[i]))
# Out:
# 100%|██████████| 5569/5569 [00:00<00:00, 7763.68it/s]

# %%
len(X)
# Out:
# 5569

# %%
# model.wv['good'].shape

# %%
# Independent Feature
X_new = np.array(X)

# %%
X_new.shape
# Out:
# (5569, 100)

# %%
# X_new[0]

# %%
X_new[0].shape
# Out:
# (100,)

# %%
# Dependent feature
y = messages[list(map(lambda x: len(x) > 0, corpus))]
y = pd.get_dummies(y['label']).astype(int)
y = y.iloc[:, 0].values

# %%
y.shape
# Out:
# (5569,)

# %%
# Reshape to converse 1 dimension to 2 demensions
# df = pd.DataFrame()
# for i in range(0, len(X)):
#     df = df.append(pd.DataFrame(X[i].reshape(1, -1)), ignore_index=True)

# %%
df_list = [pd.DataFrame(X[i].reshape(1, -1)) for i in range(len(X))]
df = pd.concat(df_list, ignore_index=True)

# %%
df.shape
# Out:
# (5569, 100)

# %%
df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.186348  0.243932  0.118255  0.120245  0.086218 -0.478862  0.158932
# 1 -0.167768  0.208376  0.098775  0.101991  0.078854 -0.405540  0.123307
# 2 -0.192071  0.260662  0.123630  0.138626  0.074928 -0.523094  0.156715
# 3 -0.253429  0.322438  0.150138  0.163393  0.116789 -0.631429  0.201269
# 4 -0.221339  0.271788  0.137776  0.139183  0.107210 -0.541975  0.173058
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.469718 -0.265031 -0.140959  ...  0.346492  0.183343  0.025630  0.060176
# 1  0.405180 -0.226070 -0.111780  ...  0.301304  0.147024  0.016183  0.043118
# 2  0.456036 -0.277486 -0.173621  ...  0.339972  0.189417  0.013780  0.039536
# 3  0.628145 -0.356907 -0.174874  ...  0.462832  0.235859  0.029070  0.082144
# 4  0.544232 -0.309951 -0.159134  ...  0.401375  0.204167  0.033628  0.074769
#
#          94        95        96        97        98        99
# 0  0.416852  0.195847  0.165016 -0.186540  0.145615  0.024471
# 1  0.345504  0.161278  0.140327 -0.167593  0.128427  0.014918
# 2  0.415354  0.181018  0.115460 -0.214482  0.170849  0.038501
# 3  0.540881  0.260292  0.229279 -0.252586  0.194720  0.027616
# 4  0.468433  0.227845  0.191727 -0.222333  0.161858  0.021964
#
# [5 rows x 100 columns]

# %%
df['Output'] = y

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.186348  0.243932  0.118255  0.120245  0.086218 -0.478862  0.158932
# 1 -0.167768  0.208376  0.098775  0.101991  0.078854 -0.405540  0.123307
# 2 -0.192071  0.260662  0.123630  0.138626  0.074928 -0.523094  0.156715
# 3 -0.253429  0.322438  0.150138  0.163393  0.116789 -0.631429  0.201269
# 4 -0.221339  0.271788  0.137776  0.139183  0.107210 -0.541975  0.173058
#
#           7         8         9  ...        91        92        93        94  \
# 0  0.469718 -0.265031 -0.140959  ...  0.183343  0.025630  0.060176  0.416852
# 1  0.405180 -0.226070 -0.111780  ...  0.147024  0.016183  0.043118  0.345504
# 2  0.456036 -0.277486 -0.173621  ...  0.189417  0.013780  0.039536  0.415354
# 3  0.628145 -0.356907 -0.174874  ...  0.235859  0.029070  0.082144  0.540881
# 4  0.544232 -0.309951 -0.159134  ...  0.204167  0.033628  0.074769  0.468433
#
#          95        96        97        98        99  Output
# 0  0.195847  0.165016 -0.186540  0.145615  0.024471       1
# 1  0.161278  0.140327 -0.167593  0.128427  0.014918       1
# 2  0.181018  0.115460 -0.214482  0.170849  0.038501       0
# 3  0.260292  0.229279 -0.252586  0.194720  0.027616       1
# 4  0.227845  0.191727 -0.222333  0.161858  0.021964       1
#
# [5 rows x 101 columns]

# %%
df.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
X = df.drop('Output', axis=1)

# %%
X.isnull().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 95    0
# 96    0
# 97    0
# 98    0
# 99    0
# Length: 100, dtype: int64

# %%
y = df['Output']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_